# %%
import pandas as pd

# %%
df= pd.read_csv("income.csv")

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.education.value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df=pd.concat([df.drop('occupation',axis=1),pd.get_dummies('occupation').add_prefix('occupation_')],axis=1)

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status relationship   race  gender  capital-gain  \
# 0           Never-married    Own-child  Black    Male             0
# ...

# %%
df= pd.read_csv("income.csv")

# %%
df=pd.concat([df.drop('occupation',axis=1),pd.get_dummies(df.occupation,dtype=int).add_prefix('occupation_')],axis=1)
df=pd.concat([df.drop('workclass',axis=1),pd.get_dummies(df.workclass,dtype=int).add_prefix('wrokclass_')],axis=1)
df=pd.concat([df.drop('marital-status',axis=1),pd.get_dummies(df['marital-status'],dtype=int).add_prefix('marital-status_')],axis=1)
df=pd.concat([df.drop('race',axis=1),pd.get_dummies(df.race,dtype=int).add_prefix('race_')],axis=1)
df=df.drop('education',axis=1)
df=pd.concat([df.drop('relationship',axis=1),pd.get_dummies(df.relationship,dtype=int).add_prefix('relationship_')],axis=1)
df=pd.concat([df.drop('native-country',axis=1),pd.get_dummies(df['native-country'],dtype=int).add_prefix('native-country_')],axis=1)

# %%
df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7    Male             0             0
# 1       38   89814                9    Male             0             0
# 2       28  336951               12    Male             0             0
# 3       44  160323               10    Male          7688             0
# 4       18  103497               10  Female             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12  Female             0             0
# 48838   40  154374                9    Male             0             0
# 48839   58  151910                9  Female             0             0
# 48840   22  201490                9    Male             0             0
# 48841   52  287927                9  Female         15024             0
#
#        hours-per-week income  occupation_?  occupation_Adm-clerical  ...  \
# ...

# %%
df['gender']=df['gender'].apply(lambda x: 1 if x=='Male' else 0)
df['income']=df['income'].apply(lambda x: 1 if x=='>50K' else 0)

# %%
df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7       1             0             0
# 1       38   89814                9       1             0             0
# 2       28  336951               12       1             0             0
# 3       44  160323               10       1          7688             0
# 4       18  103497               10       0             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12       0             0             0
# 48838   40  154374                9       1             0             0
# 48839   58  151910                9       0             0             0
# 48840   22  201490                9       1             0             0
# 48841   52  287927                9       0         15024             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  ...  \
# ...

# %%
df['income'].value_counts()
# Out:
# income
# 0    37155
# 1    11687
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(18,12))
sns.heatmap(df.corr(),annot=False,cmap='coolwarm')
# Out:
# <Axes: >

# %% [raw]
# correlations=df.corr()['income].abs()
# sorted_correlations=correlatinos.sort_values()
# num_of_cols_droped=int(0.8*len(df.columns))
# columns_to_drop=sorted_correlations.iloc[:num_of_cols_droped].index
# df_droped=df.drop(columns_to_drop,axis=1)

# %%
correlations=df.corr()['income'].abs()
sorted_correlations=correlations.sort_values()
num_of_cols_droped=int(0.8*len(df.columns))
columns_to_drop=sorted_correlations.iloc[:num_of_cols_droped].index
df_droped=df.drop(columns_to_drop,axis=1)

# %%
df_droped
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 0       25                7       1             0             0
# 1       38                9       1             0             0
# 2       28               12       1             0             0
# 3       44               10       1          7688             0
# 4       18               10       0             0             0
# ...    ...              ...     ...           ...           ...
# 48837   27               12       0             0             0
# 48838   40                9       1             0             0
# 48839   58                9       0             0             0
# 48840   22                9       1             0             0
# 48841   52                9       0         15024             0
#
#        hours-per-week  income  occupation_Exec-managerial  \
# 0                  40       0                           0
# 1                  50       0                           0
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_droped.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
df=df.drop('fnlwgt',axis=1)
train_df,test_df = train_test_split(df,test_size=0.2)

# %%
train_df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 12864   45  270535               13       1         15024             0
# 8310    39  190987               11       0             0             0
# 17368   29  201954               13       1             0             0
# 21328   26  318518               10       1             0             0
# 31841   53  268545                9       1             0             0
# ...    ...     ...              ...     ...           ...           ...
# 9067    49  195727                9       1             0             0
# 20546   32   34104                9       1          3103             0
# 7156    31  284889               13       0             0             0
# 48697   33  191335               12       1             0          1902
# 22833   37  192939                9       1             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  ...  \
# ...

# %%
test_df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 27246   52  129177               13       0             0          2824
# 42438   21  149809                9       1             0             0
# 1083    51  175122                9       0             0             0
# 34927   48  208748                3       0             0             0
# 41831   40  133974               10       1             0             0
# ...    ...     ...              ...     ...           ...           ...
# 38718   32  197457                9       0          1471             0
# 45004   37  174150               14       1             0             0
# 22975   36  358373                9       0             0             0
# 44076   84  388384                4       1             0             0
# 1368    23  238384                9       0             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  ...  \
# ...

# %%
train_x=train_df.drop('income',axis=1)
train_y=train_df['income']
test_x=test_df.drop('income',axis=1)
test_y=test_df['income']

# %%
forest = RandomForestClassifier()
forest.fit(train_x,train_y)
# Out:
# RandomForestClassifier()

# %%
forest.score(test_x,test_y)
# Out:
# 0.8479885351622479

# %%
forest.feature_importances_
# Out:
# array([2.29022261e-01, 1.27459697e-01, 1.18862509e-02, 1.13882699e-01,
#        3.67873353e-02, 1.14712250e-01, 1.55229294e-03, 5.03995024e-03,
#        7.18152631e-05, 6.02774779e-03, 1.97223816e-02, 4.23775100e-03,
#        3.15905293e-03, 4.44529514e-03, 9.25306640e-03, 2.54695203e-04,
#        1.69590775e-02, 2.74002963e-03, 6.41019009e-03, 4.16429854e-03,
#        4.10860182e-03, 1.63461926e-03, 4.99052404e-03, 5.35782214e-03,
#        1.01595367e-06, 9.18035636e-03, 6.22087949e-03, 7.69818443e-03,
#        4.33521670e-03, 8.39656808e-05, 7.61419877e-03, 2.42043665e-04,
#        7.20067343e-02, 9.25885529e-04, 2.68119190e-02, 1.62065911e-03,
#        1.70000120e-03, 1.39831777e-03, 3.18668181e-03, 4.70606139e-03,
#        9.93600257e-04, 6.21705842e-03, 4.90150710e-02, 1.00214886e-02,
#        1.97177119e-03, 8.73621055e-03, 5.28606982e-03, 8.48284228e-03,
#        2.81067212e-03, 2.50198184e-04, 1.44044467e-03, 5.04176719e-04,
# ...

# %%
forest.feature_names_in_
# Out:
# array(['age', 'educational-num', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'occupation_?', 'occupation_Adm-clerical',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_Other-service', 'occupation_Priv-house-serv',
#        'occupation_Prof-specialty', 'occupation_Protective-serv',
#        'occupation_Sales', 'occupation_Tech-support',
#        'occupation_Transport-moving', 'wrokclass_?',
#        'wrokclass_Federal-gov', 'wrokclass_Local-gov',
#        'wrokclass_Never-worked', 'wrokclass_Private',
#        'wrokclass_Self-emp-inc', 'wrokclass_Self-emp-not-inc',
#        'wrokclass_State-gov', 'wrokclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent',
# ...

# %%
importance=dict(zip(forest.feature_names_in_,forest.feature_importances_))
importance={k: v for k, v in sorted(importance.items(),key=lambda x: x[1],reverse=True)}

# %%
importance
# Out:
# {'age': np.float64(0.22902226132741382),
#  'educational-num': np.float64(0.12745969655738631),
#  'hours-per-week': np.float64(0.114712249886613),
#  'capital-gain': np.float64(0.11388269912750369),
#  'marital-status_Married-civ-spouse': np.float64(0.072006734279167),
#  'relationship_Husband': np.float64(0.049015070980963055),
#  'capital-loss': np.float64(0.03678733533077896),
#  'marital-status_Never-married': np.float64(0.026811918968435742),
#  'occupation_Exec-managerial': np.float64(0.019722381594485312),
#  'occupation_Prof-specialty': np.float64(0.016959077508343908),
#  'gender': np.float64(0.011886250892885935),
#  'relationship_Not-in-family': np.float64(0.010021488586349919),
#  'occupation_Other-service': np.float64(0.009253066401353592),
#  'wrokclass_Private': np.float64(0.009180356356596038),
#  'relationship_Own-child': np.float64(0.008736210545951157),
#  'relationship_Wife': np.float64(0.00848284227616131),
# ...

# %%
from sklearn.model_selection import GridSearchCV
param_grid ={
'n_estimators': [50, 100, 250], 'max_depth': [5, 18, 38, None], 'min_samples_split': [2, 4], 'max_features': ['sqrt', 'log2']
}
grid_search=GridSearchCV(estimator=RandomForestClassifier(),
param_grid=param_grid, verbose=10)

# %%
grid_search.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 1/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.836 total time=   0.6s
# [CV 2/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 2/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.838 total time=   0.6s
# [CV 3/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 3/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.841 total time=   0.6s
# [CV 4/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 4/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.836 total time=   0.4s
# ...

# %%
forest.score(test_x,test_y)
# Out:
# 0.8479885351622479

# %%
forest = RandomForestClassifier()
forest.fit(train_x,train_y)
# Out:
# RandomForestClassifier()

# %%
forest.score(test_x,test_y)
# Out:
# 0.8467601596888116

# %%
forest=grid_search.best_estimator_

# %%
forest.score(test_x,test_y)
# Out:
# 0.8664141672637936

# %%
importance=dict(zip(forest.feature_names_in_,forest.feature_importances_))
importance={k: v for k, v in sorted(importance.items(),key=lambda x: x[1],reverse=True)}

# %%
importance
# Out:
# {'educational-num': np.float64(0.15279683563724622),
#  'capital-gain': np.float64(0.14925525020827668),
#  'marital-status_Married-civ-spouse': np.float64(0.124541213709364),
#  'age': np.float64(0.09458925857898447),
#  'relationship_Husband': np.float64(0.07847608396045264),
#  'hours-per-week': np.float64(0.06140528914659987),
#  'capital-loss': np.float64(0.040594298205600635),
#  'occupation_Exec-managerial': np.float64(0.030371696986316258),
#  'marital-status_Never-married': np.float64(0.029381353189391623),
#  'gender': np.float64(0.02285663788082638),
#  'relationship_Not-in-family': np.float64(0.02126226949414176),
#  'occupation_Prof-specialty': np.float64(0.02034064112533495),
#  'relationship_Own-child': np.float64(0.01589200926169346),
#  'relationship_Wife': np.float64(0.014537561100980116),
#  'marital-status_Divorced': np.float64(0.010890116842346807),
#  'occupation_Other-service': np.float64(0.01052336527192904),
# ...
